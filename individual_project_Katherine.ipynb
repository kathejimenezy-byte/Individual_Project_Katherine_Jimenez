# %% [markdown]
# ## QUESTION 1: At the country level, how strongly are GDP per capita and CO₂ per capita related, and does this relationship change over time?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load data
df = pd.read_csv("owid-co2-data.csv")

# 2. (Optional but good): keep only real countries (iso_code has 3 letters)
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]

# 3. Create GDP per capita
df['gdp_per_capita'] = df['gdp'] / df['population']

# 4. Keep only needed columns and drop missing values
df_small = df[['country', 'year', 'gdp_per_capita', 'co2_per_capita']].dropna()

# 5. Correlation between GDP per capita and CO2 per capita *for each year*
corr_by_year = df_small.groupby('year').apply(
    lambda x: x['gdp_per_capita'].corr(x['co2_per_capita'])
)

# 6. Plot correlation over time
plt.figure(figsize=(6, 5))
plt.plot(corr_by_year.index, corr_by_year.values)
plt.title("Correlation: GDP per Capita vs CO₂ per Capita (by year)")
plt.xlabel("Year")
# plt.xlim([1990, 1995])
plt.ylabel("Pearson correlation")
plt.grid(True)
plt.show()

# 7. Scatter plot for one example year
year_to_plot = 2010  # change this if you want
df_year = df_small[df_small['year'] == year_to_plot]

plt.figure(figsize=(5, 5))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'])
plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_543214/404493607.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   corr_by_year = df_small.groupby('year').apply(

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load data
df = pd.read_csv("owid-co2-data.csv")

# 2. (Optional but good): keep only real countries (iso_code has 3 letters)
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]

# 3. Create GDP per capita
df['gdp_per_capita'] = df['gdp'] / df['population']

# 4. Keep only needed columns and drop missing values
df_small = df[['country', 'year', 'gdp_per_capita', 'co2_per_capita']].dropna()

# 5. Correlation between GDP per capita and CO2 per capita *for each year*
corr_by_year = df_small.groupby('year').apply(
    lambda x: x['gdp_per_capita'].corr(x['co2_per_capita'])
)

# 6. Plot correlation over time
plt.figure(figsize=(6, 5))
plt.plot(corr_by_year.index, corr_by_year.values)
plt.title("Correlation: GDP per Capita vs CO₂ per Capita (by year)")
plt.xlabel("Year")
# plt.xlim([1990, 1995])
plt.ylabel("Pearson correlation")
plt.grid(True)
plt.show()

# 7. Scatter plot for one example year
year_to_plot = 1991
df_year = df_small[df_small['year'] == year_to_plot]

plt.figure(figsize=(8, 6))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'])

# Add annotations
for _, row in df_year.iterrows():
    plt.annotate(
        row['country'],
        (row['gdp_per_capita'], row['co2_per_capita']),
        fontsize=7,
        alpha=0.7
    )

plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_543214/2152204486.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   corr_by_year = df_small.groupby('year').apply(

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load data
df = pd.read_csv("owid-co2-data.csv")

# 2. (Optional but good): keep only real countries (iso_code has 3 letters)
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]

# 3. Create GDP per capita
df['gdp_per_capita'] = df['gdp'] / df['population']

# 4. Keep only needed columns and drop missing values
df_small = df[['country', 'year', 'gdp_per_capita', 'co2_per_capita']].dropna()

# 5. Correlation between GDP per capita and CO2 per capita *for each year*
corr_by_year = df_small.groupby('year').apply(
    lambda x: x['gdp_per_capita'].corr(x['co2_per_capita'])
)

# 6. Plot correlation over time
plt.figure(figsize=(6, 5))
plt.plot(corr_by_year.index, corr_by_year.values)
plt.title("Correlation: GDP per Capita vs CO₂ per Capita (by year)")
plt.xlabel("Year")
plt.xlim([1950, 1955])
plt.ylabel("Pearson correlation")
plt.grid(True)
plt.show()

# 7. Scatter plot for one example year
year_to_plot = 1952
df_year = df_small[df_small['year'] == year_to_plot]

plt.figure(figsize=(8, 6))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'])

# Add annotations
for _, row in df_year.iterrows():
    plt.annotate(
        row['country'],
        (row['gdp_per_capita'], row['co2_per_capita']),
        fontsize=7,
        alpha=0.7
    )

plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_543214/2655010586.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   corr_by_year = df_small.groupby('year').apply(

# %%
===================================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose the year you want
year_to_plot = 2010

df_year = df[df['year'] == year_to_plot][['country', 'gdp_per_capita', 'co2_per_capita']].dropna()

# Extract X and y for regression
X = df_year[['gdp_per_capita']].values     # must be 2D
y = df_year['co2_per_capita'].values       # 1D

# Fit the model
model = LinearRegression()
model.fit(X, y)

# Regression line values
x_line = np.linspace(df_year['gdp_per_capita'].min(),
                     df_year['gdp_per_capita'].max(), 200)
y_line = model.predict(x_line.reshape(-1, 1))

# Plot scatter + regression line
plt.figure(figsize=(7, 6))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'], label="Countries", alpha=0.7)
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear regression")

plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print coefficients
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
print("R²:", model.score(X, y))
# Out:
# Intercept: 0.1351510636687241
# Slope: 0.000299038339251466
# R²: 0.6918578378037796

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load data
df = pd.read_csv("owid-co2-data.csv")

# 2. (Optional but good): keep only real countries (iso_code has 3 letters)
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]

# 3. Create GDP per capita
df['gdp_per_capita'] = df['gdp'] / df['population']

# 4. Keep only needed columns and drop missing values
df_small = df[['country', 'year', 'gdp_per_capita', 'co2_per_capita']].dropna()

# 5. Correlation between GDP per capita and CO2 per capita *for each year*
corr_by_year = df_small.groupby('year').apply(
    lambda x: x['gdp_per_capita'].corr(x['co2_per_capita'])
)

# 6. Plot correlation over time
plt.figure(figsize=(6, 5))
plt.plot(corr_by_year.index, corr_by_year.values)
plt.title("Correlation: GDP per Capita vs CO₂ per Capita (by year)")
plt.xlabel("Year")
# plt.xlim([1950, 1955])
plt.ylabel("Pearson correlation")
plt.grid(True)
plt.show()

# 7. Scatter plot for one example year
year_to_plot = 2010
df_year = df_small[df_small['year'] == year_to_plot]

plt.figure(figsize=(8, 6))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'])

# Add annotations
for _, row in df_year.iterrows():
    plt.annotate(
        row['country'],
        (row['gdp_per_capita'], row['co2_per_capita']),
        fontsize=7,
        alpha=0.7
    )

plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_543214/1154816065.py:17: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   corr_by_year = df_small.groupby('year').apply(

# %% [markdown]
# ## QUESTION 2: Can we predict the CO2 per capita from GDP per capita?

# %% [markdown]
# #first attempt: linear regresion

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose the year you want
year_to_plot = 2010

df_year = df[df['year'] == year_to_plot][['country', 'gdp_per_capita', 'co2_per_capita']].dropna()

# Extract X and y for regression
X = df_year[['gdp_per_capita']].values     # must be 2D
y = df_year['co2_per_capita'].values       # 1D

# Fit the model
model = LinearRegression()
model.fit(X, y)

# Regression line values
x_line = np.linspace(df_year['gdp_per_capita'].min(),
                     df_year['gdp_per_capita'].max(), 200)
y_line = model.predict(x_line.reshape(-1, 1))

# Plot scatter + regression line
plt.figure(figsize=(7, 6))
plt.scatter(df_year['gdp_per_capita'], df_year['co2_per_capita'], label="Countries", alpha=0.7)
plt.plot(x_line, y_line, color='red', linewidth=2, label="Linear regression")

plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot})")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# Print coefficients
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
print("R²:", model.score(X, y))
# Out:
# Intercept: 0.1351510636687241
# Slope: 0.000299038339251466
# R²: 0.6918578378037796

# %% [markdown]
# #second attempt: Quadratic model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick your year
year_to_plot = 2010
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_year['gdp_per_capita'].values.reshape(-1, 1)
y = df_year['co2_per_capita'].values.reshape(-1, 1)

# Create quadratic features: [x, x^2]
X_quad = np.hstack([x, x**2])

# Fit model
model = LinearRegression()
model.fit(X_quad, y)

# Smooth curve for plotting
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
X_line_quad = np.hstack([x_line, x_line**2])
y_line = model.predict(X_line_quad)

# Plot scatter + curve
plt.figure(figsize=(7, 6))
plt.scatter(x, y, label="Countries", alpha=0.7)
plt.plot(x_line, y_line, color="red", linewidth=2, label="Quadratic fit")
plt.title(f"GDP per Capita vs CO₂ per Capita ({year_to_plot}) — Quadratic Model")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# Print coefficients
a = model.coef_[0][1]   # coefficient of x^2
b = model.coef_[0][0]   # coefficient of x
c = model.intercept_[0]

print("Model:  y = a x^2 + b x + c")
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))
# Out:
# Model:  y = a x^2 + b x + c
# a = -2.1566663928140451e-10
# b = 0.0003165295480252545
# c = -0.021579315878808458
# R² = 0.6926617874972911

# %% [markdown]
# ## Final fitting of CO2 vs GDP for 2010

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose year
year_to_plot = 2010
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros (log undefined)
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-transform
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# Fit linear regression in log-log space
model = LinearRegression()
model.fit(logx, logy)

# Extract parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])
R2 = model.score(logx, logy)

# Create smooth curve for plotting
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Plot in original space
plt.figure(figsize=(7,6))
plt.scatter(x, y, alpha=0.7, label="Countries")
plt.plot(x_line, y_line, color='red', linewidth=2, label=f"Fit: y = a x^p")
plt.title(f"Power-Law Fit (y = a x^p) for {year_to_plot}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print parameters
print("Power-law model:  y = a x^p")
print("a =", a)
print("p =", p)
print("R² =", R2)
# Out:
# Power-law model:  y = a x^p
# a = 2.052671808748961e-05
# p = 1.2613473419966494
# R² = 0.8743642319418776

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose year
year_to_plot = 2010
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-space
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# ========== TRAIN / TEST SPLIT ==========
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth fit curve
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert back to normal space for plotting train/test
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()

# ========== PLOT ==========
plt.figure(figsize=(7,6))

# Train points (red)
plt.scatter(x_train_original, y_train_original, 
            color="red", label="Train", alpha=0.7)

# Test points (blue)
plt.scatter(x_test_original, y_test_original, 
            color="blue", label="Test", alpha=0.9)

# Fitted curve (black)
plt.plot(x_line, y_line, color="black", linewidth=2, label="Power-law fit")

plt.xscale('log')
plt.yscale('log')
plt.title(f"Power-Law Fit y = a x^p (Train=Red, Test=Blue) — {year_to_plot}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ========== METRICS ==========
print("Power-law model:  y = a x^p")
print("a =", a)
print("p =", p)
print("Train R²:", r2_score(logy_train, model.predict(logx_train)))
print("Test R² :", r2_score(logy_test,  model.predict(logx_test)))
# Out:
# Power-law model:  y = a x^p
# a = 2.0995164175626098e-05
# p = 1.2590126629377842
# Train R²: 0.8711747597991162
# Test R² : 0.8864182407628103

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Year
year_to_plot = 2010 #KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-transform
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# Train/test split
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model in log space
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth line for plotting
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert training data back to original scale
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

# Convert test data back
x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()
y_test_pred_original = np.exp(model.predict(logx_test)).flatten()

# ============================================
#  PLOT 1 — Training data + fitted curve
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(x_train_original, y_train_original, color="red", alpha=0.7, label="Train data")
plt.plot(x_line, y_line, color="black", linewidth=2, label="Fitted curve: y = a x^p")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.title(f"Training Data Fit (y = a x^p) — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ============================================
#  PLOT 2 — Predicted vs True CO2 per capita
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(y_test_original, y_test_pred_original, color="blue", alpha=0.8, label="Test data")

# 45° reference line
min_val = min(y_test_original.min(), y_test_pred_original.min())
max_val = max(y_test_original.max(), y_test_pred_original.max())
plt.plot([min_val, max_val], [min_val, max_val], color="black", linestyle="--", label="Perfect prediction")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("True CO₂ per capita")
plt.ylabel("Predicted CO₂ per capita")
plt.title(f"Predicted vs True CO₂ per Capita — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print model parameters
print("Power-law model: y = a x^p")
print("a =", a)
print("p =", p)
# Out:
# Power-law model: y = a x^p
# a = 2.0995164175626098e-05
# p = 1.2590126629377842

# %% [markdown]
# ## Fitting of CO2 vs GDP for 1965

# %%
#1965

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose year
year_to_plot = 1965
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-space
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# ========== TRAIN / TEST SPLIT ==========
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth fit curve
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert back to normal space for plotting train/test
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()

# ========== PLOT ==========
plt.figure(figsize=(7,6))

# Train points (red)
plt.scatter(x_train_original, y_train_original, 
            color="red", label="Train", alpha=0.7)

# Test points (blue)
plt.scatter(x_test_original, y_test_original, 
            color="blue", label="Test", alpha=0.9)

# Fitted curve (black)
plt.plot(x_line, y_line, color="black", linewidth=2, label="Power-law fit")

plt.xscale('log')
plt.yscale('log')
plt.title(f"Power-Law Fit y = a x^p (Train=Red, Test=Blue) — {year_to_plot}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ========== METRICS ==========
print("Power-law model:  y = a x^p")
print("a =", a)
print("p =", p)
print("Train R²:", r2_score(logy_train, model.predict(logx_train)))
print("Test R² :", r2_score(logy_test,  model.predict(logx_test)))
# Out:
# Power-law model:  y = a x^p
# a = 1.5763519928064609e-06
# p = 1.5982813384082408
# Train R²: 0.7170721306962785
# Test R² : 0.8196676137529162

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Year
year_to_plot = 1965 #KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-transform
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# Train/test split
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model in log space
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth line for plotting
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert training data back to original scale
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

# Convert test data back
x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()
y_test_pred_original = np.exp(model.predict(logx_test)).flatten()

# ============================================
#  PLOT 1 — Training data + fitted curve
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(x_train_original, y_train_original, color="red", alpha=0.7, label="Train data")
plt.plot(x_line, y_line, color="black", linewidth=2, label="Fitted curve: y = a x^p")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.title(f"Training Data Fit (y = a x^p) — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ============================================
#  PLOT 2 — Predicted vs True CO2 per capita
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(y_test_original, y_test_pred_original, color="blue", alpha=0.8, label="Test data")

# 45° reference line
min_val = min(y_test_original.min(), y_test_pred_original.min())
max_val = max(y_test_original.max(), y_test_pred_original.max())
plt.plot([min_val, max_val], [min_val, max_val], color="black", linestyle="--", label="Perfect prediction")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("True CO₂ per capita")
plt.ylabel("Predicted CO₂ per capita")
plt.title(f"Predicted vs True CO₂ per Capita — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print model parameters
print("Power-law model: y = a x^p")
print("a =", a)
print("p =", p)
# Out:
# Power-law model: y = a x^p
# a = 1.5763519928064609e-06
# p = 1.5982813384082408

# %% [markdown]
# ## Fitting of CO2 vs GDP for 1952

# %%
#1952

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Choose year
year_to_plot = 1952
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-space
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# ========== TRAIN / TEST SPLIT ==========
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth fit curve
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert back to normal space for plotting train/test
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()

# ========== PLOT ==========
plt.figure(figsize=(7,6))

# Train points (red)
plt.scatter(x_train_original, y_train_original, 
            color="red", label="Train", alpha=0.7)

# Test points (blue)
plt.scatter(x_test_original, y_test_original, 
            color="blue", label="Test", alpha=0.9)

# Fitted curve (black)
plt.plot(x_line, y_line, color="black", linewidth=2, label="Power-law fit")

plt.xscale('log')
plt.yscale('log')
plt.title(f"Power-Law Fit y = a x^p (Train=Red, Test=Blue) — {year_to_plot}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ========== METRICS ==========
print("Power-law model:  y = a x^p")
print("a =", a)
print("p =", p)
print("Train R²:", r2_score(logy_train, model.predict(logx_train)))
print("Test R² :", r2_score(logy_test,  model.predict(logx_test)))
# Out:
# Power-law model:  y = a x^p
# a = 3.305615766299886e-07
# p = 1.7843384386398655
# Train R²: 0.647935026001721
# Test R² : 0.6803838374243569

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Year
year_to_plot = 1952
df_year = df[df['year'] == year_to_plot][['gdp_per_capita','co2_per_capita']].dropna()

x = df_year['gdp_per_capita'].values
y = df_year['co2_per_capita'].values

# Remove zeros
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-transform
logx = np.log(x).reshape(-1, 1)
logy = np.log(y).reshape(-1, 1)

# Train/test split
logx_train, logx_test, logy_train, logy_test = train_test_split(
    logx, logy, test_size=0.2, random_state=42
)

# Fit model in log space
model = LinearRegression()
model.fit(logx_train, logy_train)

# Extract power-law parameters
p = model.coef_[0][0]
a = np.exp(model.intercept_[0])

# Smooth line for plotting
x_line = np.linspace(x.min(), x.max(), 300)
y_line = a * (x_line ** p)

# Convert training data back to original scale
x_train_original = np.exp(logx_train).flatten()
y_train_original = np.exp(logy_train).flatten()

# Convert test data back
x_test_original = np.exp(logx_test).flatten()
y_test_original = np.exp(logy_test).flatten()
y_test_pred_original = np.exp(model.predict(logx_test)).flatten()

# ============================================
#  PLOT 1 — Training data + fitted curve
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(x_train_original, y_train_original, color="red", alpha=0.7, label="Train data")
plt.plot(x_line, y_line, color="black", linewidth=2, label="Fitted curve: y = a x^p")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.title(f"Training Data Fit (y = a x^p) — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ============================================
#  PLOT 2 — Predicted vs True CO2 per capita
# ============================================
plt.figure(figsize=(7,6))
plt.scatter(y_test_original, y_test_pred_original, color="blue", alpha=0.8, label="Test data")

# 45° reference line
min_val = min(y_test_original.min(), y_test_pred_original.min())
max_val = max(y_test_original.max(), y_test_pred_original.max())
plt.plot([min_val, max_val], [min_val, max_val], color="black", linestyle="--", label="Perfect prediction")

plt.xscale("log")
plt.yscale("log")
plt.xlabel("True CO₂ per capita")
plt.ylabel("Predicted CO₂ per capita")
plt.title(f"Predicted vs True CO₂ per Capita — {year_to_plot}")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print model parameters
print("Power-law model: y = a x^p")
print("a =", a)
print("p =", p)
# Out:
# Power-law model: y = a x^p
# a = 3.305615766299886e-07
# p = 1.7843384386398655

# %% [markdown]
# ## QUESTION 3: Do countries exhibit evidence for an Environmental Kuznets Curve (EKC)?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "United States"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}", fontsize =20)
plt.xlabel("GDP per capita", fontsize =20)
plt.ylabel("CO₂ per capita", fontsize =20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid(True)
plt.legend(fontsize = 15)
plt.tight_layout()
plt.savefig("name.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# Country: United States
# a = -3.0661427158313845
# b = 0.0015299159861645244
# c = -2.232926303602167e-08
# R² = 0.9104525991815747
# EKC turning point GDP per capita = 34258.09404673269

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "Canada"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Country: Canada
# a = -0.7050899367083279
# b = 0.0011858798823314754
# c = -1.881080504168461e-08
# R² = 0.9377873109792173
# EKC turning point GDP per capita = 31521.242171814923

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "Germany"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Country: Germany
# a = -0.16931029944206522
# b = 0.0010881451164431511
# c = -2.0399942297275675e-08
# R² = 0.8707553696632451
# EKC turning point GDP per capita = 26670.298880905862

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "Bolivia"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Country: Bolivia
# a = -1.186920658956983
# b = 0.0006657259977428306
# c = -2.830690309051613e-08
# R² = 0.8653904501418579
# EKC turning point GDP per capita = 11759.075085219649

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "Nepal"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Country: Nepal
# a = 0.034727343157611126
# b = -9.395116189673346e-05
# c = 8.084315678254977e-08
# R² = 0.9704622017482848
# No EKC (no inverted-U shape)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("owid-co2-data.csv")
df = df[df['iso_code'].notna() & (df['iso_code'].str.len() == 3)]
df['gdp_per_capita'] = df['gdp'] / df['population']

# Pick the country you want
country = "China"   # ← change this to test another country

df_country = df[df['country'] == country][['year','gdp_per_capita','co2_per_capita']].dropna()

# Extract x and y
x = df_country['gdp_per_capita'].values.reshape(-1, 1)
y = df_country['co2_per_capita'].values.reshape(-1, 1)

# Quadratic features
X_quad = np.hstack([x, x**2])

# Fit model y = a + b x + c x^2
model = LinearRegression()
model.fit(X_quad, y)

a = model.intercept_[0]
b = model.coef_[0][0]
c = model.coef_[0][1]

print("Country:", country)
print("a =", a)
print("b =", b)
print("c =", c)
print("R² =", model.score(X_quad, y))

# Turning point (if EKC exists)
if c < 0:
    turning_point = -b / (2*c)
    print("EKC turning point GDP per capita =", turning_point)
else:
    print("No EKC (no inverted-U shape)")

# Plot curve
x_line = np.linspace(x.min(), x.max(), 300).reshape(-1, 1)
y_line = model.predict(np.hstack([x_line, x_line**2]))

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label="Historical data")
plt.plot(x_line, y_line, color="green", linewidth=2, label="Quadratic fit")
plt.title(f"EKC Test for {country}")
plt.xlabel("GDP per capita")
plt.ylabel("CO₂ per capita")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Country: China
# a = -0.4743646865121689
# b = 0.0009396128881674824
# c = -2.672525642870597e-08
# R² = 0.9837462595157693
# EKC turning point GDP per capita = 17579.11828973568

# %% [markdown]
# ## QUESTION 4: Does global CO₂ help predict global temperature anomalies?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# ==============================
# 1. Load GLOBAL CO2 (OWID)
# ==============================
co2 = pd.read_csv("owid-co2-data.csv")

# Keep only the global aggregate ("World")
co2_world = co2[co2["country"] == "World"][["year", "co2"]].rename(
    columns={"co2": "co2_global"}
)

# Optional: focus on modern era
co2_world = co2_world[co2_world["year"] >= 1960]

# ==============================
# 2. Load NASA temperature data
# ==============================
# First row in GLB.Ts+dSST.csv is metadata, so skip it
temp = pd.read_csv("GLB.Ts+dSST.csv", skiprows=1)

# Keep Year and annual mean (J-D)
temp = temp[["Year", "J-D"]].rename(columns={
    "Year": "year",
    "J-D": "temp_anomaly"
})

# Convert to numeric (some early values may be '***')
temp["temp_anomaly"] = pd.to_numeric(temp["temp_anomaly"], errors="coerce")

# Same period and drop missing
temp = temp[temp["year"] >= 1960].dropna(subset=["temp_anomaly"])

# ==============================
# 3. Merge CO2 + temperature
# ==============================
df = pd.merge(co2_world, temp, on="year", how="inner").dropna()

X = df[["co2_global"]]        # feature: global CO2 emissions
y = df["temp_anomaly"]        # target: global temp anomaly

# ==============================
# 4. Train/Test split
# ==============================
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=True,
    random_state=42
)

# ==============================
# 5. Fit linear regression
# ==============================
model = LinearRegression()
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print("R² (train):", r2_score(y_train, y_train_pred))
print("R² (test): ", r2_score(y_test, y_test_pred))
print("RMSE (test):", np.sqrt(mean_squared_error(y_test, y_test_pred)))
print("Slope (β):", model.coef_[0])
print("Intercept (α):", model.intercept_)

# ==============================
# 6. PLOT 1: Training data + best-fit curve
#    x = true CO2 (train), y = true temp anomaly (train)
# ==============================
# Sort training data by CO2 for a smooth line
X_train_sorted = X_train.sort_values(by="co2_global")
y_train_sorted = y_train.loc[X_train_sorted.index]
y_line = model.predict(X_train_sorted)

plt.figure(figsize=(7, 6))
plt.scatter(X_train["co2_global"], y_train, alpha=0.7, label="Training data")
plt.plot(X_train_sorted["co2_global"], y_line,
         color="red", linewidth=2, label="Best-fit line")

plt.xlabel("Global CO₂ emissions (GtCO₂ per year)")
plt.ylabel("Temperature anomaly (°C)")
plt.title("TRAINING SET: Temp anomaly vs CO₂\nwith best-fit linear curve")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# ==============================
# 7. PLOT 2: Test true vs predicted temp anomaly
#    x = true temp anomaly (test), y = predicted temp anomaly (test)
# ==============================
plt.figure(figsize=(7, 6))
plt.scatter(y_test, y_test_pred, alpha=0.7, label="Test points")

# 1:1 reference line
min_val = min(y_test.min(), y_test_pred.min())
max_val = max(y_test.max(), y_test_pred.max())
plt.plot([min_val, max_val], [min_val, max_val],
         color="red", linewidth=2, label="y = x (perfect prediction)")

plt.xlabel("True temperature anomaly (°C)")
plt.ylabel("Predicted temperature anomaly (°C)")
plt.title("TEST SET: True vs Predicted Temperature Anomaly")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# R² (train): 0.8932361924090585
# R² (test):  0.8781025912375002
# RMSE (test): 0.15265425765587584
# Slope (β): 3.761281424080223e-05
# Intercept (α): -0.5116897574934782
